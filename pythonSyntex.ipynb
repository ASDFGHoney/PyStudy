# %%
print('Hello world!')
# Out:
# Hello world!

# %%
1+1
# Out:
# 2

# %%
#들여쓰기 주의하기
1+1
  1+1
# Out:
#   File "<ipython-input-3-de43291d77c3>", line 3
#     1+1
#     ^
# IndentationError: unexpected indent

# %%
#한줄 주석
'''
여러줄 주석
ㅎㅎㅎㅎ
ㅎㅎㅎ
'''
# Out:
# python

# %%
#변수 여러개 한번에 만들기
a, b = 100, 10000
print(a,b)
# Out:
# 100 10000

# %%
# Out:
# /content
